# %%
# !pip install scikit-image

# %%
import skimage

# %%
#rabota s ksrtinkoi

# %%
from skimage import io
img = io.imread('Lenna.png')

# %%
#вывод картинки

# %%
io.imshow(img)

# %%
img
# Out:
# array([[[227, 138, 111],
#         [226, 134, 108],
#         [225, 132, 110],
#         ...,
#         [194,  84,  86],
#         [188,  82,  85],
#         [185,  79,  84]],
#
#        [[227, 136, 111],
#         [227, 133, 110],
#         [225, 130, 109],
#         ...,
#         [190,  88,  86],
#         [181,  80,  80],
#         [177,  76,  80]],
#
#        [[225, 134, 110],
#         [225, 132, 109],
#         [225, 131, 110],
#         ...,
#         [184,  84,  81],
#         [178,  81,  83],
#         [174,  77,  81]],
#
#        ...,
#
#        [[ 81,  30,  60],
#         [ 83,  27,  59],
#         [ 80,  19,  55],
#         ...,
#         [187,  77,  87],
#         [184,  87,  86],
#         [185,  83,  85]],
#
#        [[ 84,  27,  58],
#         [ 85,  26,  57],
#         [ 83,  19,  54],
#         ...,
#         [186,  68,  80],
#         [192,  73,  83],
#         [193,  74,  85]],
#
#        [[ 84,  24,  58],
#         [ 85,  22,  57],
#         [ 84,  16,  56],
# ...

# %%
img[0]
# Out:
# array([[227, 138, 111],
#        [226, 134, 108],
#        [225, 132, 110],
#        ...,
#        [194,  84,  86],
#        [188,  82,  85],
#        [185,  79,  84]], dtype=uint8)

# %%
img.shape
# Out:
# (2048, 2048, 3)

# %%
from skimage import io, color, data
img = io.imread('Lenna.png')
img_hsv = color.rgb2hsv(img)
io.imshow(img_hsv, cmap='hsv')

# %%
img_hsv
# Out:
# array([[[0.0387931 , 0.51101322, 0.89019608],
#         [0.03672316, 0.52212389, 0.88627451],
#         [0.03188406, 0.51111111, 0.88235294],
#         ...,
#         [0.9969697 , 0.56701031, 0.76078431],
#         [0.99528302, 0.56382979, 0.7372549 ],
#         [0.99213836, 0.57297297, 0.7254902 ]],
#
#        [[0.03591954, 0.51101322, 0.89019608],
#         [0.03276353, 0.5154185 , 0.89019608],
#         [0.03017241, 0.51555556, 0.88235294],
#         ...,
#         [0.00320513, 0.54736842, 0.74509804],
#         [0.        , 0.55801105, 0.70980392],
#         [0.99339934, 0.57062147, 0.69411765]],
#
#        [[0.03478261, 0.51111111, 0.88235294],
#         [0.03304598, 0.51555556, 0.88235294],
#         [0.03043478, 0.51111111, 0.88235294],
#         ...,
#         [0.00485437, 0.55978261, 0.72156863],
#         [0.99656357, 0.54494382, 0.69803922],
#         [0.99312715, 0.55747126, 0.68235294]],
#
#        ...,
#
#        [[0.90196078, 0.62962963, 0.31764706],
# ...

# %%
rgb_img = color.hsv2rgb(img_hsv)
io.imshow(rgb_img)

# %%
img = io.imread('Lenna.png')
img_xyz = color.rgb2xyz(img)
io.imshow(img_xyz)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#сохранить картинку

# %%
io.imsave('Lenna_xyz.png', img_xyz)
# Out:
# Lossy conversion from float64 to uint8. Range [0.0007950397620348449, 1.088754]. Convert image to uint8 prior to saving to suppress this warning.

# %%
import numpy as np

# %%
grey = np.array([
    [
        [136, 133, 133],
        [196, 196, 196],
        [196, 196, 196]
    ],
    [
        [196, 196, 196],
        [255, 255, 255],
        [50, 50, 50]
    ],
    [
        [50, 50, 50],
        [196, 196, 196],
        [255, 255, 255],
    ]
], dtype = np.uint8)

# %%
io.imshow(grey)

# %%
# !pip install opencv-python

# %%
import cv2
treu_grey = cv2.cvtColor(grey, cv2.COLOR_BGR2GRAY)
median_blured = cv2.medianBlur(treu_grey, 3)

# %%
back_bgr = cv2.cvtColor(median_blured, cv2.COLOR_GRAY2BGR)

# %%
io.imshow(back_bgr)

# %%
import math
function = lambda x,y,sigma:(1 / (2 * math.pi*sigma**2))*math.e**-((x**2+y**2)/2*sigma**2)

# %%
s=0.84

# %%
for i in range(3):
    for j in range(3):
        print(f"{i}-{j}-{function(1-i, 1-j, s)}")
# Out:
# 0-0-0.11138414438220091
# 0-1-0.1585048174500937
# 0-2-0.11138414438220091
# 1-0-0.1585048174500937
# 1-1-0.22555972660416007
# 1-2-0.1585048174500937
# 2-0-0.11138414438220091
# 2-1-0.1585048174500937
# 2-2-0.11138414438220091

# %%
img_bilateral = cv2.bilateralFilter(grey, 2, 100, 50)

# %%
img_bgr = cv2.cvtColor(img_bilateral, cv2.COLOR_BGR2GRAY)

# %%
io.imshow(img_bgr)

# %%
io.imshow(img)

# %%
img = cv2.imread('Lenna.png')

# %%
_, img_thr = cv2.threshold(img, 90, 200, 0)

# %%
io.imshow(img_thr)

# %%
table = cv2.imread('sudoku.jpg')

# %%
table_grey = cv2.cvtColor(table, cv2.COLOR_BGR2GRAY)

# %%
_, table_thr = cv2.threshold(table_grey, 80, 255, 0)

# %%
io.imshow(table_thr)

# %%
th2 = cv2.adaptiveThreshold(table_grey, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)

# %%
io.imshow(th2)

# %%
th3 = cv2.adaptiveThreshold(table_grey, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

# %%
io.imshow(th3)

# %%
! pip install skimage==0.16.2
# Out:
# ERROR: Could not find a version that satisfies the requirement skimage==0.16.2 (from versions: 0.0)
# ERROR: No matching distribution found for skimage==0.16.2

# %%
from skimage import io
from skimage.metrics import structural_similarity

# %%
img_cat1 = io.imread('cat1.jpg')
img_cat2 = io.imread('cat2.jpg')
img_dog = io.imread('dog1.jpg')

# %%
import cv2
import numpy as np

# %%
img_cat2 = cv2.resize(img_cat2, dsize=img_cat1.shape[:2])
img_dog = cv2.resize(img_dog, dsize=img_cat1.shape[:2])

# %%
ssim_original = structural_similarity(img_cat1, img_cat1,
                    data_range=img_cat1.max() - img_cat1.min(), multichannel=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7044\2515289000.py:1: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_original = structural_similarity(img_cat1, img_cat1,

# %%
ssim_original
# Out:
# 1.0

# %%
ssim_cat = structural_similarity(img_cat1, img_cat2,
               data_range=img_cat2.max()-img_cat2.min(), multichannel=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7044\1503657979.py:1: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_cat = structural_similarity(img_cat1, img_cat2,

# %%
ssim_cat
# Out:
# 0.18161097666160245

# %%
ssim_dog = structural_similarity(img_cat1, img_dog,
               data_range=img_cat1.max()-img_cat1.min(), multichannel=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7044\2408539005.py:1: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_dog = structural_similarity(img_cat1, img_dog,

# %%
ssim_dog
# Out:
# 0.1639412274122816
